# %% [markdown]
# **<a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/K87ByXmr/stage5.jpg);font-family:camtasia;font-size:120%;color:white;text-align:center;border-radius:15px 50px; padding:7px"> Welcome to my notebook</p>

# %% [markdown]
# # 1. Introduction

# %% [markdown]
#  ** Leaf disease detection** is a critical aspect of modern agriculture and plant science. It involves the identification and diagnosis of diseases that affect the leaves of plants. These diseases can significantly impact crop yield, quality, and overall plant health, making their early detection and management essential for sustainable agriculture.

# %% [markdown]
# #  Importance of Leaf Disease Detection:
#
# **Crop Health and Yield:** Healthy leaves are vital for photosynthesis, which is the process that enables plants to produce energy and grow. Leaf diseases can reduce photosynthesis, leading to decreased crop yield and quality.
#
# **Early Detection:** Identifying leaf diseases in their early stages is crucial for effective management. Early detection allows farmers and researchers to implement timely interventions, such as applying fungicides or adjusting irrigation, to prevent disease spread and minimize damage.
#
# **Crop Protection:** Leaf diseases can spread rapidly in agricultural fields, leading to significant economic losses. Detecting and controlling these diseases help protect crops and ensure food security.

# %% [markdown]
# # **Import requirment libraries and tools**

# %%
import numpy as np
import cv2
import os
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Activation
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # import directory and path

# %%
directory='/kaggle/input/leaf-data'
categories=['Strawberry_fresh','Strawberry_scrotch']

# %% [markdown]
# # path connection

# %%
data=[]
for categori in categories:
    folder=os.path.join(directory,categori)
    print(folder)
    label=categories.index(categori)# we defined label in categories
    
    for img in os.listdir(folder):
        img=os.path.join(folder,img)#connection between folder and image
        
        #print(img)
        img_arr=cv2.imread(img)#convert image to array
        #plt.imshow(img_arr)
        #break #f we want image show
        
        img_arr=cv2.resize(img_arr,(100,100))
        
        data.append([img_arr,label])
# Out:
# /kaggle/input/leaf-data/Strawberry_fresh
# /kaggle/input/leaf-data/Strawberry_scrotch

# %%
#data#show image array and label

# %%
random.shuffle(data)#convert sequence data to random data

# %%
x=[]#image array 
y=[]#label array
for features,label in data:
    x.append(features)
    y.append(label)

# %%
X=np.array(x)#convert feature list to array
Y=np.array(y)#convert label list to array

# %% [markdown]
# # Normalize

# %%
X=X/255#rescalling

# %%
X.shape#1st 100 means 100 image then 100*100 image size and then 3 means rgb
# Out:
# (100, 100, 100, 3)

# %% [markdown]
# # proceesing complete

# %%
model=Sequential()

# %% [markdown]
# filter size 32 and kernel size 3*3,input shape 100*100

# %%
model=Sequential()
model.add(Conv2D(32,(3,3),input_shape=X.shape[1:],activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())#connect final layer
model.add(Dense(2,activation='softmax'))#final output 2

# %% [markdown]
# # compile and detect loss

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# #X is independent variable and Y is dependent variable and 10% data test and 90% train

# %%
model.fit(X,Y,epochs=15,validation_split=0.1)
# Out:
# Epoch 1/15
# 3/3 [==============================] - 8s 161ms/step - loss: 2.5803 - accuracy: 0.4889 - val_loss: 5.1381 - val_accuracy: 0.4000
# Epoch 2/15
# 3/3 [==============================] - 0s 20ms/step - loss: 4.1871 - accuracy: 0.5111 - val_loss: 0.8349 - val_accuracy: 0.4000
# Epoch 3/15
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1885 - accuracy: 0.5111 - val_loss: 1.4960 - val_accuracy: 0.6000
# Epoch 4/15
# 3/3 [==============================] - 0s 18ms/step - loss: 1.5913 - accuracy: 0.5000 - val_loss: 0.2543 - val_accuracy: 0.9000
# Epoch 5/15
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4411 - accuracy: 0.8333 - val_loss: 0.6494 - val_accuracy: 0.7000
# Epoch 6/15
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6352 - accuracy: 0.6889 - val_loss: 0.2561 - val_accuracy: 0.9000
# Epoch 7/15
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2854 - accuracy: 0.8444 - val_loss: 0.3050 - val_accuracy: 0.8000
# Epoch 8/15
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3141 - accuracy: 0.8111 - val_loss: 0.1691 - val_accuracy: 0.9000
# Epoch 9/15
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1303 - accuracy: 0.9778 - val_loss: 0.2475 - val_accuracy: 0.9000
# Epoch 10/15
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1802 - accuracy: 0.9000 - val_loss: 0.2588 - val_accuracy: 0.9000
# Epoch 11/15
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1127 - accuracy: 0.9444 - val_loss: 0.1340 - val_accuracy: 0.9000
# Epoch 12/15
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0928 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9000
# Epoch 13/15
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0594 - accuracy: 1.0000 - val_loss: 0.1862 - val_accuracy: 0.9000
# Epoch 14/15
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0504 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.9000
# Epoch 15/15
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0451 - accuracy: 1.0000 - val_loss: 0.1811 - val_accuracy: 0.9000

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 32)       0
#  )
#
#  flatten (Flatten)           (None, 76832)             0
#
#  dense (Dense)               (None, 2)                 153666
#
# =================================================================
# Total params: 154,562
# Trainable params: 154,562
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # model prediction

# %%
#from keras.preprocessing import image
import keras.utils as image
from keras.utils import load_img, img_to_array
import numpy as np
img_pred=image.load_img('/kaggle/input/leaf-data/Strawberry_fresh/02caa98d-1c74-43b3-b3ee-e8492998f82a___RS_HL 2090.JPG',target_size=(100,100))
img_pred=image.img_to_array(img_pred)
img_pred=np.expand_dims(img_pred,axis=0)#increase one dimention

result=model.predict(img_pred)
print(result)
if result[0][0]>result[0][1]:
    prediction="Straberry_fresh"
    
else:
    prediction="Straberry_scroch"
    
print(prediction)
# Out:
# 1/1 [==============================] - 0s 102ms/step
# [[1. 0.]]
# Straberry_fresh

# %% [markdown]
# # Conclusion
# Leaf disease detection is vital for agriculture, protecting crops from diseases that harm yield and quality. Advanced methods like visual inspection, remote sensing, machine learning, and molecular techniques help identify diseases early. These technologies enable proactive measures, ensuring sustainable and productive farming while minimizing environmental impact.

# %% [markdown]
# # References:

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#240b36;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px; color:white;"> We appreciate your interest in this notebook. Consider it  Up Vote if you liked it and thought the content was valuable </p>
# </div>
